# %%
pi=3.14
def addition(x,y):
    return x+y
def subraction(x,y):
    return x-y
def multiplication(x,y):
    retutn x*y
def division(x,y):
    return x/y
def area(x,y):
    return pi*r*r
addition(3,7)
# Out:
#   Cell In[3], line 7
#     retutn x*y
#            ^
# SyntaxError: invalid syntax
